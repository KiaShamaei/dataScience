# %%
# !pip install seaborn
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.9/294.9 kB 672.5 kB/s eta 0:00:001m673.2 kB/s eta 0:00:01
# ...

# %%
import seaborn as sns
import numpy as np
import pandas as pd

# %%
data = np.random.normal(0,10,(5,5))
data
# Out:
# array([[ -1.55430482,  -8.41929798,  -7.4734227 , -14.58448151,
#          14.83763991],
#        [-10.34112683,  -1.10681347,   0.19748999,   5.89174197,
#           0.99183971],
#        [ 13.28629767,  -0.4190275 , -19.48590101,  -6.92350656,
#          -7.37102591],
#        [ 12.82461461, -18.68469513,   8.82103299, -14.99973068,
#          -0.6969978 ],
#        [  0.91270275,   9.41094118,  24.57907773,   6.35504834,
#          -6.27011321]])

# %%
sns.heatmap(data)
# Out:
# <Axes: >

# %%
#with add count to each cell
sns.heatmap(data, annot=True)
# Out:
# <Axes: >

# %%
dataSample = pd.read_csv('Iris.csv')

# %%
dataSample
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
dataSample = dataSample.drop("Id" , axis=1)

# %%
sns.pairplot(dataSample);

# %%
sns.pairplot(dataSample , hue="Species");

# %%
#in this par twe make 3d vector to use  for category base )
sns.scatterplot(dataSample , x = 'SepalLengthCm' , y='PetalWidthCm' , hue='Species')
# Out:
# <Axes: xlabel='SepalLengthCm', ylabel='PetalWidthCm'>
