# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
y = np.random.normal(0,10,(1000,))
x= np.arange(1000)
plt.scatter(x,y)
plt.plot([1000,0] ,[0,0] , '--r')
plt.plot([1000,0] ,[0,0] , '--r')
plt.plot([1000,0] ,[10,0] , '--y')
