# %%
import numpy as np 
import matplotlib.pyplot as plt

# %%
data = np.random.normal(0,100,(10000,))
data2 = np.random.uniform(0,100,(10000,))

# %%
plt.hist(data, bins=200 , density = True );

# %%
out = plt.hist(data, bins=100)
out;

# %%
out1 = plt.hist(data, bins=10)
out1;

# %%
out1[2].get_children()

# %%
out2 = plt.hist(data, bins=10)
rbins5 = out2[2].get_children()[5]

rbins5.set_color("#FF0000")
