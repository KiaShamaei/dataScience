# %%
import numpy as nu
import matplotlib.pyplot as mt

# %%
a = nu.random.normal(size=(100,))
mt.ylim(1,20)
mt.plot(a*10)

# %%
users = nu.array(['rex','rana','ali'])
rank = nu.array([-1,0,0.5])
maxium  = nu.max(rank)
filterC = maxium == rank
users[filterC]
# Out:
# array(['ali'], dtype='<U4')

# %% [markdown]
# ```
# find max with argmax
# ```
