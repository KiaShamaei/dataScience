# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error, r2_score

# %%
x=np.array([1,2,3,4,5,6,7,8])
y = np.array([0,0,0,0,0,1,1,1])
plt.scatter(x,y)
plt.plot([0,5.5,5.5,10],[0,0,1,1] , 'r');

# %%
model = linear_model.LogisticRegression()
model.fit(x.reshape(-1,1),y.reshape(-1))
# Out:
# LogisticRegression()

# %%
model.score(x.reshape(-1,1) , y)
# Out:
# 1.0

# %% [markdown]
# ### load data frame iris and work on type of it

# %%
#first load data set \
dataRaw = datasets.load_iris(as_frame=True)

# %%
data = dataRaw['data']

# %%
data
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# [150 rows x 4 columns]

# %%
data['target'] = dataRaw['target']

# %%
data
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      target
# 0         0
# ...

# %%
#how to find number of class in data if taget is type int only 
data['target'].unique()
# Out:
# array([0, 1, 2])

# %%
#other type use astype to category 
data['target'].astype('category').describe()
# Out:
# count     150
# unique      3
# top         0
# freq       50
# Name: target, dtype: int64

# %%
sns.pairplot(data)

# %%
sns.pairplot(data , hue='target')

# %% [markdown]
# for 1 test choice 0 and 1 make model and analysis it

# %%
data1 = data[data['target'] != 2]

# %%
data1['target'].unique()
# Out:
# array([0, 1])

# %% [markdown]
# make train and test part

# %%
x1 =data1.drop('target' , axis=1).values
y1 = data1['target'].values
x_train1 ,  x_test1 , y_train1 , y_test1 = train_test_split(x1,y1, test_size=0.1, shuffle=True)

# %%
model = linear_model.LogisticRegression()

# %%
model.fit(x_train1,y_train1)
# Out:
# LogisticRegression()

# %%
model.score(x_train1,y_train1)
# Out:
# 1.0

# %%
model.score(x_test1,y_test1)
# Out:
# 1.0

# %% [markdown]
# change parameter to check it now select 1 , 2

# %%
data2 = data[data['target']!= 0]

# %%
x2= data2.drop('target' , axis = 1).values
y2= data2['target'].values
x_train2 ,  x_test2 , y_train2 , y_test2 = train_test_split(x2,y2, test_size=0.1, shuffle=True)
model2 = linear_model.LogisticRegression(C=0.6 , dual=True)

# %%
model.fit(x_train2 , y_train2)
# Out:
# LogisticRegression()

# %%
model.score(x_train2,y_train2)
# Out:
# 0.9555555555555556

# %%
model.score(x_test2,y_test2)
# Out:
# 1.0
