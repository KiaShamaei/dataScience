# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import pandas as pd
from sklearn import datasets
from sklearn.cluster import KMeans

# %%
X,y = datasets.load_iris(return_X_y=True)

# %%
plt.scatter(X[:,0],X[:,3], marker='.' , c=y)
